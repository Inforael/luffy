# %%
#### Bibliotecas 
# 
# - pip install pandas 
# - pip install plotly
# - pip install nbformat
# - pip install openpyxl.

# %%
#### Instalação do pip no notebook

! pip install pandas

# %% [markdown]
# Carregamento Excel

# %%
import openpyxl
import pandas as pd

estoque = pd.read_excel("Lista de Produto.xlsx")

# %%
estoque.head()
# Out:
#    Numero  Publico   seguimeto                 Tipo  \
# 0        1   Salão  Tratamento  Cronograma Capilar
# 1        2    Casa  Tratamento  Cronograma Capilar
# 2        3   Salão  Tratamento  Cronograma Capilar
# 3        4    Casa  Tratamento  Cronograma Capilar
# 4        5   Salão  Tratamento  Cronograma Capilar
#
#                             Descrição                  Produto    Valor   \
# 0                          Hidratante          SH. CRONOTRAT- 1L    19.8
# 1      Nutrientes ,desembaraço,macies      BÁLSAMO CRONOTRAT- 1L    19.8
# 2                                 NaN              KIT CRONOTRAT    35.0
# 3  Oleosidade,reduz o frizz,da brilho  MASC. QATAR IMPACTO- 5006    15.4
# 4  Oleosidade,reduz o frizz,da brilho   MASC. QATAR IMPACTO- 1KG    26.4
#
#    Valor Surgerido  Valor de Venda   Site Troia Hair  Site Shopee  \
# 0             39.0             40.0            43.35        37.45
# 1             39.0             40.0            43.35        37.45
# ...

# %%
estoque.tail()
# Out:
#      Numero  Publico                      seguimeto  \
# 200      201   Salão        CREME PARA AS MÃOS 70G
# 201      202   Salão  POTENCIALIZADDR DE TRATAMENTO
# 202      203   Salão       EQUIPAMENTO E ACESSORIOS
# 203      204   Salão                  FINALIZADORES
# 204      205   Salão                LINHA MASCULINA
#
#                                      Tipo Descrição  \
# 200               CREME PARA AS MÃOS 70G        NaN
# 201               NANOFIXER QUERANTINA 5L       NaN
# 202           PISTOLA PULVERIZADORA TROIA       NaN
# 203  VINAGRE DE MAÇÃ BRILHO INTENSO 300ML       NaN
# 204       POMADA CAPILAR EM PO  WHITE- 8G       NaN
#
#                                 Produto    Valor   Valor Surgerido  \
# 200               CREME PARA AS MÃOS 70G      7.7            13.00
# 201               NANOFIXER QUERANTINA 5L    89.9           289.00
# 202           PISTOLA PULVERIZADORA TROIA   169.9           249.99
# ...
